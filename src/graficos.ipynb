# %%
import matplotlib.pyplot as plt

data1 = {
    'MLP': 53.84,
    'relu_4_layer_divrand': 52.35,
    'relu_6_layer_divrand': 55.19,
    'relu_layer_div2': 55.81,
    'relu_layer_div4': 54.17,
    'relu_layer_div2_div4': 52.52
}

data2 = {
    'simple_cnn': 71.03,
    'simple_cnn_arq_2': 74.78,
    'simple_cnn_arq_4': 74.44,
    'default_conv': 61.51,
    'rn50': 83.7
}

data3 = {
    'rn50_leaky_relu': 83.93,
    'rn50_silu': 83.87,
    'rn50_elu': 84.38,
    'rn50_sigmoid': 67.5,
    'rn50': 83.7
}

data4 = {
    'rn50_elu_adadelta_bien': 86.25,
    'rn50_elu_sgd_expo_sheduler': 78.99,
    'rn50_elu_adagrad_bien': 77.39,
    'rn50_elu_adadelta_expo_sheduler': 74.82,
    'rn50_elu_sgd_bien': 84.2
}

data5 = {
    'rn50_elu_adadelta_opt': 87.04,
    'rn50_elu_adadelta_dropout.2': 88.18,
    'rn50_elu_adadelta_dropout.5': 87.66
}

def create_bar_graph(data, title, colors):
    names = list(data.keys())
    values = data.values()
    
    plt.figure(figsize=(10, 6))
    plt.barh(names, values, color=colors)
    plt.title(title, fontweight='bold', color='#363A3D')

    plt.tick_params(axis='y', which='both', left=False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)

    plt.yticks(color='#6B6B76')

    plt.xlim(50, 85)
    plt.xticks(range(50, 86, 5))
    plt.xticks(color='#6B6B76')
    
    plt.show()

# %%
custom_colors = ['#A1A9AD', '#5BC5DB', '#A12864', '#7D54B2', '#E57439', '#479A5F']
create_bar_graph(data1, 'Accuracy en la mejor epoch', custom_colors)

# %%
custom_colors = ['#E09AB1', '#A12864', '#EDB732', '#5BC5DB', '#479A5F']
create_bar_graph(data2, 'Accuracy en la mejor epoch', custom_colors)

# %%
custom_colors = ['#5387DD', '#E87B9F', '#5BC5DB', '#DA4C4C', '#479A5F']
create_bar_graph(data3, 'Accuracy en la mejor epoch', custom_colors)

# %%
custom_colors = ['#F0B899', '#5387DD', '#7D54B2', '#E87B9F', '#A0C75C']
create_bar_graph(data4, 'Accuracy en la mejor epoch', custom_colors)

# %%
custom_colors = ['#E87B9F', '#E57439', '#479A5F']
create_bar_graph(data5, 'Accuracy en la mejor epoch', custom_colors)
